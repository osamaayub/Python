# %% [markdown]
# Create a stack called magazine, and  add bullets in it and after every bullet shot display the status of the magazine.

# %%
Magazine=list()
Magazine.append('.')
display(Magazine)
Magazine.append('.')
display(Magazine)
Magazine.append('.')
display(Magazine)
Magazine.append('.')
display(Magazine)

# %% [markdown]
# Create a queue and insert numbers in it and pop only that two number that have highest product.

# %%
MyQueue=list()
MyQueue.append(1)
MyQueue.append(2)
MyQueue.append(3)
MyQueue.append(4)

display(MyQueue)
product=MyQueue.pop(3)*MyQueue.pop(2)
print(product)
display(MyQueue)

# %% [markdown]
# Create a doubly linked list.

# %%
class Node(object):
    def __init__(self, data, Next = None, Previous = None):
        self.data = data
        self.next = Next
        self.previous = Previous

    def getNext(self):
        return self.next

    def getPrevious(self):
        return self.previous

    def getData(self):
        return self.data

    def setData(self, newData):
        self.data = newData

    def setNext(self, newNext):
        self.next = newNext

    def setPrevious(self, newPrevious):
        self.previous = newPrevious


class DoublyLinkedList(object):
    def __init__(self):
        self.head = None

    def isEmpty(self):
        return self.head == None

    def insertFirst(self, data):
        newNode = Node(data)
        if self.head:
            self.head.setPrevious(newNode)
        newNode.setNext(self.head)
        self.head = newNode

    def insertLast(self, data):
        newNode = Node(data)
        current = self.head
        while current.getNext() != None:
            current = current.getNext()
        current.setNext(newNode)
        newNode.setPrevious(current)

    def getAllData(self):
        ''' This function displays the data elements of the Linked List '''
        current = self.head
        elements = []
        while current:
            elements.append(current.getData())
            current = current.getNext()

        return elements

    def remove(self,item):
        current = self.head
        previous = None
        found = False
        while not found:
            if current.getData() == item:
                found = True
            else:
                previous = current
                current = current.getNext()

        if previous == None:
            self.head = current.getNext()
        else:
            previous.setNext(current.getNext())

if __name__ == '__main__':
    myList = DoublyLinkedList()
    myList.insertFirst(1)
    myList.insertFirst(12)
    myList.insertFirst(32)
    myList.insertFirst(22)
    myList.insertLast(2)
    myList.remove(12)
    print(myList.getAllData())

# %% [markdown]
# Create a tree and add values to it and after that traverse it in such a way that first you will print leafs and then thier parents and so on.

# %%
class Node:
    def __init__(self,Value):
        self.LeftChild=None
        self.Data=Value
        self.RightChild=None
class BinarySearchTree:
    def createNewNode(self,Data):
        return Node(Data)
    def InsertNode(self,Node,Data):
        if Node is None:
            return self.createNewNode(Data)
        if Data<Node.Data:
            Node.LeftChild=self.InsertNode(Node.LeftChild,Data)
        elif Data>Node.Data:
            Node.RightChild=self.InsertNode(Node.RightChild,Data)
        return Node
    def PostOrderTraversal(self,Root):
        if Root is not None:
            self.PostOrderTraversal(Root.LeftChild)
            self.PostOrderTraversal(Root.RightChild)
            print(Root.Data)
Root=None
BinarySearchTree=BinarySearchTree()
Root=BinarySearchTree.InsertNode(Root,10)
BinarySearchTree.InsertNode(Root,20)
BinarySearchTree.InsertNode(Root,30)
BinarySearchTree.InsertNode(Root,40)
BinarySearchTree.InsertNode(Root,50)
BinarySearchTree.InsertNode(Root,60)
BinarySearchTree.InsertNode(Root,70)
BinarySearchTree.PostOrderTraversal(Root)

# %% [markdown]
# Create a grapgh and check that which edge has a common vertices

# %%
Graph={"a":["b,c"],
       "b":["c,d"],
       "c":["e,f"],
       "d":["f,g"],
       "e":["i,h"]       
} 
Edge=Graph.values()
print(Edge)
print(Graph)

# %% [markdown]
# Create a hash table and sort it according to its keys.

# %%
HashTable={"Name":"Hamza","Age":23,"RegistrationNumber":"L1S18BSCS0123"}
HashTable.update({"Course":"DSA"})
for i in sorted(HashTable.keys()):
    print(i)

# %% [markdown]
# Design and implement a class named Car that have private attributes name, number of doors and fuel economy. You have to implement the default constructor along with setters getters. Interface will perform required tasks and display the information about two Cars.
#
# <b>Input:</b>
# <br>
# Name of the Car: Chevrolet<br>
# Total Number of Doors: 4<br>
# Fuel Economy of the Car (Km/Liter): 11.5<br>

# %%
class car: 
    def __init__(self):
        self.__carname="BMW"
        self.__numberofdoors=4
        self.__fueleconomy=22.5
    def set_carname(self,carname):
        self.__carname=carname
    def set_noofDoors(self,noofdoors):
        self.__numberofdoors=noofdoors
    def set_fuelEconomy(self,fuel_economy):
        self.__fueleconomy=fuel_economy
    def get_name(self):
        return self.__carname
    def get_numberofDoor(self):
        return self.__numberofdoors
    def get_fuelEconomy(self):
        return self.__fueleconomy
    def show(self):
        print(self.__carname)
        print(self.__numberofdoors)
        print(self.__fueleconomy)
car1=car()
car1.set_carname("RangeRover")
print(car1.get_name())
car1.set_noofDoors(4)
print(car1.get_numberofDoor())
car1.set_fuelEconomy(12.5)
print(car1.get_fuelEconomy())
car2=car()
car2.set_carname("Toyota Corolla")
print(car2.get_name())
car1.set_noofDoors(4)
print(car1.get_numberofDoor())
car1.set_fuelEconomy(13.5)
print(car1.get_fuelEconomy())

# %% [markdown]
# Design and implement a class named Student that have private attributes name, id, cell# and cgpa. You have to implement the default constructor along with setters getters. Interface will perform required tasks and display the information about three Students including their grade.
#
# <br><b>Note:</b> The grade will be awarded to students according to their final cgpa.
#
# <b>Input:</b>
# <br>Name of the Student: Adeel Anwar
# <br>Id of the Student: L1F12BSCS2099
# <br>Cell# of the Student: 03009999999
# <br>CGPA of the Student: 3

# %%
class Student:
    def __init__(self):
        self.__StudentName="Inshal Naveed" 
        self.__StudentID="L1S18BSCS0156"
        self.__StudentCell_no="03314828005"
        self.__StudentCgpa=3.56
    def Set_studentName(self,Name):
        self.__StudentName=Name
    def Set_studentID(self,ID):
        self.__StudentID=ID
    def Set_StudentCellNo(self,CellNo):
        self.__StudentCell_no=CellNo
    def Student_CGPA(self,cgpa):
        self.__StudentCgpa=cgpa
    def get_studentName(self):
        return self.__StudentName
    def get_studentID(self):
        return self.__StudentID
    def get_Student_CellNo(self):
        return self.__StudentCell_no
    def get_CGPA(self):
        return self.__StudentCgpa
    def show(self):
        print(self.__StudentName)
        print(self.__StudentID)
        print(self.__StudentCell_no)
        print(self.__Student_Cgpa)
    
Student1=Student()
Student1.Set_studentName("Hamza Mansoor")
print(Student1.get_studentName())
Student1.Set_studentID("L1S18BSCS0123")
print(Student1.get_studentID())
Student1.Set_StudentCellNo("03314829005")
print(Student1.get_Student_CellNo())
Student1.Student_CGPA(2.76)
print("Student1 grade is B-")
print(Student1.get_CGPA())
Student2=Student()
Student2.Set_studentName("Inshal Naveed")
print(Student2.get_studentName())
Student2.Set_studentID("L1S18BSCS0156")
print(Student2.get_studentID())
Student2.Set_StudentCellNo("033148677921")
print(Student2.get_Student_CellNo())
Student2.Student_CGPA(2.56)
print("Student2 Grade is C+")
print(Student2.get_CGPA())

Student3=Student()
Student3.Set_studentName("Osama Ayub")
print(Student3.get_studentName())
Student3.Set_studentID("L1S18BSCS0095")
print(Student3.get_studentID())
Student3.Set_StudentCellNo("03314828005")
print(Student3.get_Student_CellNo())
Student3.Student_CGPA(2.30)
print("Student3 grade is C-")
print(Student3.get_CGPA())
# Out:
#   File "<ipython-input-2-9f5a88128c54>", line 38
#     print(Student1.get_CGPA())
#     ^
# IndentationError: expected an indented block

# %% [markdown]
# Next bridge software house Lahore requires an application that calculates employee’s increment on the given criteria. For the purpose software house wants his software engineer to design the application using object oriented approach. The class “NextBridge” is required to create with attributes and functions as mentioned below:
#
# <br>>name
# <br>>address
# <br>>phoneNumber
# <br>>level//fresh,junior,senior
# <br>>experience in years
#
# Implement the class having a parametrized constructor along with setters and getters. Also define a function that can calculate increment criteria based on the table below:
#
# <br>Experience&nbsp;&nbsp;&nbsp;&nbsp;Increment
# <br>0&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;0%
# <br>1-2&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;10%
# <br>2-5&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;25%
# <br>5 to onward&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;45%

# %%
class NextBridge:
    def __init__(self,name,address,phoneNo,level,experience):
        self.__name=name
        self.__Address=address
        self.__PhoneNumber=phoneNo
        self.__Level=level
        self.__Experience=experience
    def Set_name(self,name):
        self.__name=name
    def get_name(self):
        return self.__name
    def show(self):
        print(self.__name)
        print(self.__Address)
        print(self.__PhoneNumber)
        print(self.__Level)
        print(self.__Experience)
    def set_Address(self,address):
        self.__Address=address
    def get_Address(self):
        return self.__Address
    def set_PhoneNo(self,phone_no):
        self.__PhoneNumber=phone_no
    def get_phone_No(self):
        return self.__PhoneNumber
    def set_level(self,level):
        self.__Level=level
    def get_level(self):
        return self.__Level
    def set_experience(self,exp):
        self.__Experience=exp
    def get_experience(self):
        return self.__Experience
    def Increment(self,experience):
        increment=experience*0.35*10
        print(increment)
        
NextBridge1=NextBridge('osama Ayub','170SD house Lane8 Askari 5','03314828005','Junior level',"3 Year")
NextBridge1.show()
print("increase in the Salary\n")
NextBridge1.Increment(3)
